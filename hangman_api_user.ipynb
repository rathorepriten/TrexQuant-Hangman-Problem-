# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.training_words
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
from hangman_bilstm_inference import *
# Out:
# Hangman model loaded successfully!

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):

        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        # Load the dictionary for fallback method
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
        # Initialize the model
        print("Initializing Hangman model...")
        initialize_model()
    
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link
  
    def guess(self, word):
        """
        Advanced guess function for the Hangman API.
        
        Args:
            word: Current state of the word with underscores (e.g., "_ p p _ e")
            
        Returns:
            A single letter as your guess
        """
        # Get the letter from the model
        guess_letter = model_guess(word, set(self.guessed_letters))
        
        # Fallback to dictionary approach if model gives an already guessed letter
        # or if the model failed to load
        if guess_letter in self.guessed_letters:
            # Clean the word for dictionary matching
            clean_word = word[::2].replace("_", ".")
            len_word = len(clean_word)
            
            # Find matching words from dictionary
            current_dictionary = self.current_dictionary
            new_dictionary = []
            
            for dict_word in current_dictionary:
                if len(dict_word) != len_word:
                    continue
                if re.match(clean_word, dict_word):
                    new_dictionary.append(dict_word)
            
            self.current_dictionary = new_dictionary
            
            # Count character frequencies in matching words
            full_dict_string = "".join(new_dictionary)
            c = collections.Counter(full_dict_string)
            sorted_letter_count = c.most_common()
            
            # Get the most frequent letter that hasn't been guessed
            guess_letter = '!'
            for letter, instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break
            
            # If no matches in dictionary, use global letter frequency
            if guess_letter == '!' or guess_letter in self.guessed_letters:
                sorted_letter_count = self.full_dictionary_common_letter_sorted
                for letter, instance_count in sorted_letter_count:
                    if letter not in self.guessed_letters:
                        guess_letter = letter
                        break
        
        return guess_letter
    

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="ed8a20fa1abd67f8db6a8fd115888d", timeout=2000)
# Out:
# Initializing Hangman model...
# Hangman model loaded successfully!

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
for i in range(0,20):
    time.sleep(2)
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
    print('\n\n')
# Out:
# Successfully start a new game! Game ID: 587a1276bc3d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ l _ e _ _ _ _ l e '}
# Guessing letter: i
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ l _ e _ _ _ _ l e '}
# Guessing letter: v
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ l _ e _ _ _ _ l e '}
# Guessing letter: b
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b l _ e b _ _ _ l e '}
# Guessing letter: u
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 3, 'word': 'b l u e b _ _ _ l e '}
# Guessing letter: a
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 2, 'word': 'b l u e b _ _ _ l e '}
# Guessing letter: d
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 1, 'word': 'b l u e b _ _ _ l e '}
# Guessing letter: t
# Sever response: {'game_id': '587a1276bc3d', 'status': 'ongoing', 'tries_remains': 1, 'word': 'b l u e b _ t t l e '}
# Guessing letter: o
# Sever response: {'game_id': '587a1276bc3d', 'status': 'success', 'tries_remains': 1, 'word': 'b l u e b o t t l e '}
# Successfully finished game: 587a1276bc3d
# run 391 practice games out of an allotted 100,000. practice success rate so far = 0.573
#
#
#
# Successfully start a new game! Game ID: fd7cd5d2a2ae. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ t '}
# Guessing letter: s
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ t '}
# Guessing letter: n
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ t '}
# Guessing letter: f
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ t '}
# Guessing letter: l
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ t '}
# Guessing letter: r
# Sever response: {'game_id': 'fd7cd5d2a2ae', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ t '}
# Failed game: fd7cd5d2a2ae. Because of: # of tries exceeded!
# run 392 practice games out of an allotted 100,000. practice success rate so far = 0.571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 for i in range(0,20):
# ----> 2     time.sleep(2)
#       3     api.start_game(practice=1,verbose=True)
#       4     [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(0, 1000, 1):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    recorded_success_rate = total_recorded_successes / total_recorded_runs
    print('run %d recorded games. success rate so far = %.3f' % (total_recorded_runs, recorded_success_rate))
    print('\n\n')
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Successfully start a new game! Game ID: 7f51845ab18c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ s '}
# Guessing letter: a
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ _ _ _ s '}
# Guessing letter: r
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r a _ _ _ _ s '}
# Guessing letter: t
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ _ s '}
# Guessing letter: g
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a _ _ _ g s '}
# Guessing letter: n
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n n _ g s '}
# Guessing letter: o
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n n o g s '}
# Guessing letter: b
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a n n o g s '}
# Guessing letter: f
# Sever response: {'game_id': '7f51845ab18c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a n n o g s '}
# Guessing letter: c
# Sever response: {'game_id': '7f51845ab18c', 'status': 'success', 'tries_remains': 2, 'word': 'c r a n n o g s '}
# Successfully finished game: 7f51845ab18c
# run 515 recorded games. success rate so far = 0.573
#
#
#
# Playing  1  th game
# Successfully start a new game! Game ID: 9812518f11da. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ e _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ e n _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ c _ e n c _ '}
# Guessing letter: i
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ i c i e n c _ '}
# Guessing letter: f
# Sever response: {'game_id': '9812518f11da', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e f f i c i e n c _ '}
# Guessing letter: y
# Sever response: {'game_id': '9812518f11da', 'status': 'success', 'tries_remains': 5, 'word': 'e f f i c i e n c y '}
# Successfully finished game: 9812518f11da
# run 516 recorded games. success rate so far = 0.574
#
#
#
# Playing  2  th game
# Successfully start a new game! Game ID: 43b1e91b119e. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a r _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a r m _ '}
# Guessing letter: n
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ a r m _ '}
# Guessing letter: s
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ a r m s '}
# Guessing letter: d
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ a r m s '}
# Guessing letter: w
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ a r m s '}
# Guessing letter: b
# Sever response: {'game_id': '43b1e91b119e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ a r m s '}
# Guessing letter: l
# Sever response: {'game_id': '43b1e91b119e', 'status': 'success', 'tries_remains': 1, 'word': 'a l a r m s '}
# Successfully finished game: 43b1e91b119e
# run 517 recorded games. success rate so far = 0.574
#
#
#
# Playing  3  th game
# Successfully start a new game! Game ID: cbe3f341a347. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ e d '}
# Guessing letter: r
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ r _ _ r e _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ r _ _ r e t t e d '}
# Guessing letter: s
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ r _ _ r e t t e d '}
# Guessing letter: u
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ r _ u r e t t e d '}
# Guessing letter: c
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ c _ r _ u r e t t e d '}
# Guessing letter: a
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ c a r _ u r e t t e d '}
# Guessing letter: b
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'ongoing', 'tries_remains': 5, 'word': 'b _ c a r b u r e t t e d '}
# Guessing letter: i
# Sever response: {'game_id': 'cbe3f341a347', 'status': 'success', 'tries_remains': 5, 'word': 'b i c a r b u r e t t e d '}
# Successfully finished game: cbe3f341a347
# run 518 recorded games. success rate so far = 0.575
#
#
#
# Playing  4  th game
# Successfully start a new game! Game ID: f3d298faefa3. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ a '}
# Guessing letter: l
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ a '}
# Guessing letter: t
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a '}
# Guessing letter: r
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ a '}
# Guessing letter: n
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n _ n _ a '}
# Guessing letter: d
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n _ n d a '}
# Guessing letter: o
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'ongoing', 'tries_remains': 1, 'word': 'n _ n d a '}
# Guessing letter: e
# Sever response: {'game_id': 'f3d298faefa3', 'status': 'failed', 'tries_remains': 0, 'word': 'n _ n d a '}
# Failed game: f3d298faefa3. Because of: # of tries exceeded!
# run 519 recorded games. success rate so far = 0.574
#
#
#
# Playing  5  th game
# Successfully start a new game! Game ID: 912c99c5104b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ e _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ e _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r s e _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ n _ e r s e _ _ _ _ n _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n _ e r s e _ _ _ _ n _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ e r s e _ _ i _ n _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r s e _ t i _ n _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r s e _ t i o n _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r s e c t i o n _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '912c99c5104b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r s e c t i o n a _ '}
# Guessing letter: l
# Sever response: {'game_id': '912c99c5104b', 'status': 'success', 'tries_remains': 5, 'word': 'i n t e r s e c t i o n a l '}
# Successfully finished game: 912c99c5104b
# run 520 recorded games. success rate so far = 0.575
#
#
#
# Playing  6  th game
# Successfully start a new game! Game ID: 702c09c8ad22. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ _ _ _ a e '}
# Guessing letter: i
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ _ i _ a e '}
# Guessing letter: d
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ d i d a e '}
# Guessing letter: o
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ o _ o d i d a e '}
# Guessing letter: p
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ o p o d i d a e '}
# Guessing letter: c
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a c _ o p o d i d a e '}
# Guessing letter: r
# Sever response: {'game_id': '702c09c8ad22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a c r o p o d i d a e '}
# Guessing letter: m
# Sever response: {'game_id': '702c09c8ad22', 'status': 'success', 'tries_remains': 5, 'word': 'm a c r o p o d i d a e '}
# Successfully finished game: 702c09c8ad22
# run 521 recorded games. success rate so far = 0.576
#
#
#
# Playing  7  th game
# Successfully start a new game! Game ID: a81b6d955124. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ _ _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ _ _ _ r _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ _ _ _ r _ '}
# Guessing letter: m
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ _ _ _ r m '}
# Guessing letter: o
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ _ _ o r m '}
# Guessing letter: f
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ _ f o r m '}
# Guessing letter: i
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ i f o r m '}
# Guessing letter: l
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l _ _ i f o r m '}
# Guessing letter: c
# Sever response: {'game_id': 'a81b6d955124', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c a l _ c i f o r m '}
# Guessing letter: y
# Sever response: {'game_id': 'a81b6d955124', 'status': 'success', 'tries_remains': 2, 'word': 'c a l y c i f o r m '}
# Successfully finished game: a81b6d955124
# run 522 recorded games. success rate so far = 0.577
#
#
#
# Playing  8  th game
# Successfully start a new game! Game ID: 3122a03764a2. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ e d '}
# Guessing letter: l
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e l l _ _ _ _ _ e d '}
# Guessing letter: w
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'w e l l _ _ _ _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'w e l l t _ _ _ _ e d '}
# Guessing letter: r
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'w e l l t r _ _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'w e l l t r a _ _ e d '}
# Guessing letter: i
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 5, 'word': 'w e l l t r a _ _ e d '}
# Guessing letter: n
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 4, 'word': 'w e l l t r a _ _ e d '}
# Guessing letter: k
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 3, 'word': 'w e l l t r a _ _ e d '}
# Guessing letter: s
# Sever response: {'game_id': '3122a03764a2', 'status': 'ongoing', 'tries_remains': 2, 'word': 'w e l l t r a _ _ e d '}
# Guessing letter: p
# Sever response: {'game_id': '3122a03764a2', 'status': 'success', 'tries_remains': 2, 'word': 'w e l l t r a p p e d '}
# Successfully finished game: 3122a03764a2
# run 523 recorded games. success rate so far = 0.577
#
#
#
# Playing  9  th game
# Successfully start a new game! Game ID: 6479e1ceaa2b. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ a _ '}
# Guessing letter: l
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ '}
# Guessing letter: s
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ a _ '}
# Guessing letter: n
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ n _ a n '}
# Guessing letter: i
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i _ n i a n '}
# Guessing letter: o
# Sever response: {'game_id': '6479e1ceaa2b', 'status': 'success', 'tries_remains': 3, 'word': 'i o n i a n '}
# Successfully finished game: 6479e1ceaa2b
# run 524 recorded games. success rate so far = 0.578
#
#
#
# Playing  10  th game
# Successfully start a new game! Game ID: 57b12531b54d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r _ _ _ _ _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ t e r _ _ _ _ _ _ e r '}
# Guessing letter: n
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n t e r _ _ _ _ _ n e r '}
# Guessing letter: i
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r _ _ _ _ _ n e r '}
# Guessing letter: o
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r _ o _ _ o n e r '}
# Guessing letter: m
# Sever response: {'game_id': '57b12531b54d', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n t e r _ o m m o n e r '}
# Guessing letter: c
# Sever response: {'game_id': '57b12531b54d', 'status': 'success', 'tries_remains': 5, 'word': 'i n t e r c o m m o n e r '}
# Successfully finished game: 57b12531b54d
# run 525 recorded games. success rate so far = 0.579
#
#
#
# Playing  11  th game
# Successfully start a new game! Game ID: 4ddb461e460c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: n
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: m
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: r
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: l
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ _ _ _ _ e d '}
# Guessing letter: i
# Sever response: {'game_id': '4ddb461e460c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ _ i _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': '4ddb461e460c', 'status': 'failed', 'tries_remains': 0, 'word': 'e _ _ i _ _ e d '}
# Failed game: 4ddb461e460c. Because of: # of tries exceeded!
# run 526 recorded games. success rate so far = 0.578
#
#
#
# Playing  12  th game
# Successfully start a new game! Game ID: d8ffec3cb9de. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ _ e _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ _ e _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r a _ _ e _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r a n _ e _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n _ e _ _ _ '}
# Guessing letter: g
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n g e _ _ _ '}
# Guessing letter: b
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a n g e _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a n g e _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r a n g e _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o r a n g e _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o r a n g e _ s _ '}
# Guessing letter: u
# Sever response: {'game_id': 'd8ffec3cb9de', 'status': 'failed', 'tries_remains': 0, 'word': 'o r a n g e _ s _ '}
# Failed game: d8ffec3cb9de. Because of: # of tries exceeded!
# run 527 recorded games. success rate so far = 0.577
#
#
#
# Playing  13  th game
# Successfully start a new game! Game ID: cf4affd72b6b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ e d '}
# Guessing letter: r
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r _ _ _ e _ _ _ _ _ e d '}
# Guessing letter: i
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r _ _ _ e _ _ _ _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r _ _ _ e t _ _ _ _ e d '}
# Guessing letter: k
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r _ _ _ e t _ _ _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ e t _ _ a _ e d '}
# Guessing letter: p
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ e t _ _ a p e d '}
# Guessing letter: s
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ e t s _ a p e d '}
# Guessing letter: h
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ e t s h a p e d '}
# Guessing letter: n
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r a _ _ e t s h a p e d '}
# Guessing letter: g
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ _ e t s h a p e d '}
# Guessing letter: c
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a _ _ e t s h a p e d '}
# Guessing letter: m
# Sever response: {'game_id': 'cf4affd72b6b', 'status': 'failed', 'tries_remains': 0, 'word': 'r a _ _ e t s h a p e d '}
# Failed game: cf4affd72b6b. Because of: # of tries exceeded!
# run 528 recorded games. success rate so far = 0.576
#
#
#
# Playing  14  th game
# Successfully start a new game! Game ID: 84e6fcd65aa1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r i _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '84e6fcd65aa1', 'status': 'success', 'tries_remains': 3, 'word': 't r i g g i n g '}
# Successfully finished game: 84e6fcd65aa1
# run 529 recorded games. success rate so far = 0.577
#
#
#
# Playing  15  th game
# Successfully start a new game! Game ID: 8a4137638a1e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ a _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n n a _ _ _ n _ '}
# Guessing letter: i
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n n a _ _ i n _ '}
# Guessing letter: g
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a n n a _ _ i n g '}
# Guessing letter: c
# Sever response: {'game_id': '8a4137638a1e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c a n n a _ _ i n g '}
# Guessing letter: l
# Sever response: {'game_id': '8a4137638a1e', 'status': 'success', 'tries_remains': 3, 'word': 'c a n n a l l i n g '}
# Successfully finished game: 8a4137638a1e
# run 530 recorded games. success rate so far = 0.577
#
#
#
# Playing  16  th game
# Successfully start a new game! Game ID: d55300d96abf. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd55300d96abf', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd55300d96abf', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ _ _ '}
# Failed game: d55300d96abf. Because of: # of tries exceeded!
# run 531 recorded games. success rate so far = 0.576
#
#
#
# Playing  17  th game
# Successfully start a new game! Game ID: 81d0c69d3e50. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ r _ _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ r _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ r _ _ _ _ _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ r i _ _ _ _ i a '}
# Guessing letter: m
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ r i _ _ _ _ i a '}
# Guessing letter: l
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ r i _ _ _ _ i a '}
# Guessing letter: n
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ r i _ _ _ _ i a '}
# Guessing letter: p
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ r i p _ _ _ i a '}
# Guessing letter: u
# Sever response: {'game_id': '81d0c69d3e50', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ r i p _ _ _ i a '}
# Failed game: 81d0c69d3e50. Because of: # of tries exceeded!
# run 532 recorded games. success rate so far = 0.575
#
#
#
# Playing  18  th game
# Successfully start a new game! Game ID: f3e9f4eba9d1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ t _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ t _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ _ _ t _ _ _ n '}
# Guessing letter: a
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ _ t _ _ _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 3, 'word': 's o _ o t _ _ _ n '}
# Guessing letter: l
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 3, 'word': 's o l o t _ _ _ n '}
# Guessing letter: r
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 3, 'word': 's o l o t _ _ r n '}
# Guessing letter: h
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'ongoing', 'tries_remains': 3, 'word': 's o l o t h _ r n '}
# Guessing letter: u
# Sever response: {'game_id': 'f3e9f4eba9d1', 'status': 'success', 'tries_remains': 3, 'word': 's o l o t h u r n '}
# Successfully finished game: f3e9f4eba9d1
# run 533 recorded games. success rate so far = 0.576
#
#
#
# Playing  19  th game
# Successfully start a new game! Game ID: 7b76c0821136. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ r _ _ _ _ _ _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e u r _ _ _ _ _ _ _ _ '}
# Guessing letter: y
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e u r y _ _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y _ a _ _ _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y _ a _ _ _ _ d '}
# Guessing letter: i
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y _ a i _ _ i d '}
# Guessing letter: o
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y _ a i _ o i d '}
# Guessing letter: l
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e u r y l a i _ o i d '}
# Guessing letter: c
# Sever response: {'game_id': '7b76c0821136', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e u r y l a i _ o i d '}
# Guessing letter: m
# Sever response: {'game_id': '7b76c0821136', 'status': 'success', 'tries_remains': 2, 'word': 'e u r y l a i m o i d '}
# Successfully finished game: 7b76c0821136
# run 534 recorded games. success rate so far = 0.577
#
#
#
# Playing  20  th game
# Successfully start a new game! Game ID: 9eb0a56aed6a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ e r _ _ _ _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p r e _ _ _ e r _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ _ _ e r _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ e r _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ e r _ t _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ _ _ e r _ t o o _ '}
# Guessing letter: n
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ n _ e r _ t o o _ '}
# Guessing letter: s
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ n _ e r s t o o _ '}
# Guessing letter: d
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ n d e r s t o o d '}
# Guessing letter: u
# Sever response: {'game_id': '9eb0a56aed6a', 'status': 'success', 'tries_remains': 4, 'word': 'p r e u n d e r s t o o d '}
# Successfully finished game: 9eb0a56aed6a
# run 535 recorded games. success rate so far = 0.578
#
#
#
# Playing  21  th game
# Successfully start a new game! Game ID: bc4701dfe7c2. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ n _ '}
# Guessing letter: i
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ i _ n _ '}
# Guessing letter: o
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ i o n _ '}
# Guessing letter: s
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ i o n s '}
# Guessing letter: x
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ i o n s '}
# Guessing letter: t
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ t i o n s '}
# Guessing letter: c
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ _ t i o n s '}
# Guessing letter: u
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ u _ _ t i o n s '}
# Guessing letter: l
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ u l _ t i o n s '}
# Guessing letter: a
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ u l a t i o n s '}
# Guessing letter: m
# Sever response: {'game_id': 'bc4701dfe7c2', 'status': 'success', 'tries_remains': 4, 'word': 'e m u l a t i o n s '}
# Successfully finished game: bc4701dfe7c2
# run 536 recorded games. success rate so far = 0.578
#
#
#
# Playing  22  th game
# Successfully start a new game! Game ID: 7adfb6536788. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ _ _ e _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ r _ _ _ e _ _ _ e r _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r a _ _ e _ _ _ e r _ a _ e '}
# Guessing letter: t
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r a _ _ e _ _ _ e r _ a t e '}
# Guessing letter: p
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p a r a _ _ e _ _ _ e r _ a t e '}
# Guessing letter: m
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p a r a _ _ e _ _ _ e r _ a t e '}
# Guessing letter: s
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p a r a _ _ e _ _ _ e r _ a t e '}
# Guessing letter: i
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p a r a _ _ e _ i _ e r _ a t e '}
# Guessing letter: n
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p a r a _ _ e _ i n e r _ a t e '}
# Guessing letter: l
# Sever response: {'game_id': '7adfb6536788', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p a r a l l e l i n e r _ a t e '}
# Guessing letter: v
# Sever response: {'game_id': '7adfb6536788', 'status': 'success', 'tries_remains': 4, 'word': 'p a r a l l e l i n e r v a t e '}
# Successfully finished game: 7adfb6536788
# run 537 recorded games. success rate so far = 0.579
#
#
#
# Playing  23  th game
# Successfully start a new game! Game ID: b5c189b0da25. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r e _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ r e _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ r e _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o r e _ o '}
# Guessing letter: c
# Sever response: {'game_id': 'b5c189b0da25', 'status': 'failed', 'tries_remains': 0, 'word': '_ o r e _ o '}
# Failed game: b5c189b0da25. Because of: # of tries exceeded!
# run 538 recorded games. success rate so far = 0.578
#
#
#
# Playing  24  th game
# Successfully start a new game! Game ID: 01cd93613637. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ s _ _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ s t _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ s t i _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ a s t i _ a _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ a s t i c a _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '01cd93613637', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e l a s t i c a l l _ '}
# Guessing letter: y
# Sever response: {'game_id': '01cd93613637', 'status': 'success', 'tries_remains': 5, 'word': 'e l a s t i c a l l y '}
# Successfully finished game: 01cd93613637
# run 539 recorded games. success rate so far = 0.579
#
#
#
# Playing  25  th game
# Successfully start a new game! Game ID: 398c73a43d8d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ r e _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ r e _ t _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ r e a t _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e c r e a t _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e c r e a t i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '398c73a43d8d', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e c r e a t i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '398c73a43d8d', 'status': 'success', 'tries_remains': 6, 'word': 'r e c r e a t i o n '}
# Successfully finished game: 398c73a43d8d
# run 540 recorded games. success rate so far = 0.580
#
#
#
# Playing  26  th game
# Successfully start a new game! Game ID: 775ae2611aa9. # of tries remaining: 6. Word: _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: m
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '775ae2611aa9', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '775ae2611aa9', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ e '}
# Failed game: 775ae2611aa9. Because of: # of tries exceeded!
# run 541 recorded games. success rate so far = 0.579
#
#
#
# Playing  27  th game
# Successfully start a new game! Game ID: 7d5087965c16. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7d5087965c16', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '7d5087965c16', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e _ _ _ e s s '}
# Guessing letter: l
# Sever response: {'game_id': '7d5087965c16', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l _ _ e s s '}
# Guessing letter: f
# Sever response: {'game_id': '7d5087965c16', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l f _ e s s '}
# Guessing letter: n
# Sever response: {'game_id': '7d5087965c16', 'status': 'success', 'tries_remains': 6, 'word': 's e l f n e s s '}
# Successfully finished game: 7d5087965c16
# run 542 recorded games. success rate so far = 0.579
#
#
#
# Playing  28  th game
# Successfully start a new game! Game ID: cfbc49915a63. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ r _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ r _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ _ r _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ _ r _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ _ r _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'cfbc49915a63', 'status': 'failed', 'tries_remains': 0, 'word': 's _ _ r _ _ '}
# Failed game: cfbc49915a63. Because of: # of tries exceeded!
# run 543 recorded games. success rate so far = 0.578
#
#
#
# Playing  29  th game
# Successfully start a new game! Game ID: b9175bf21b28. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ t _ _ _ _ _ _ t e '}
# Guessing letter: a
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ t _ _ t _ _ _ _ _ a t e '}
# Guessing letter: n
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ n t _ _ t _ _ _ _ _ a t e '}
# Guessing letter: o
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o n t o _ t _ _ _ _ _ a t e '}
# Guessing letter: r
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ o n t o r t _ _ _ _ _ a t e '}
# Guessing letter: c
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c o n t o r t _ _ _ _ c a t e '}
# Guessing letter: i
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 6, 'word': 'c o n t o r t _ _ _ i c a t e '}
# Guessing letter: f
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 5, 'word': 'c o n t o r t _ _ _ i c a t e '}
# Guessing letter: l
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 5, 'word': 'c o n t o r t _ _ l i c a t e '}
# Guessing letter: p
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'ongoing', 'tries_remains': 5, 'word': 'c o n t o r t _ p l i c a t e '}
# Guessing letter: u
# Sever response: {'game_id': 'b9175bf21b28', 'status': 'success', 'tries_remains': 5, 'word': 'c o n t o r t u p l i c a t e '}
# Successfully finished game: b9175bf21b28
# run 544 recorded games. success rate so far = 0.579
#
#
#
# Playing  30  th game
# Successfully start a new game! Game ID: 1a3b1dab23e4. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1a3b1dab23e4', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '1a3b1dab23e4', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ r _ _ e _ r _ '}
# Guessing letter: y
# Sever response: {'game_id': '1a3b1dab23e4', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ r _ _ e _ r y '}
# Guessing letter: t
# Sever response: {'game_id': '1a3b1dab23e4', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ r _ _ e t r y '}
# Guessing letter: m
# ...
# Successfully finished game: b57915c70ebb
# run 990 recorded games. success rate so far = 0.594
#
#
#
# Playing  476  th game
# Successfully start a new game! Game ID: 726c7bde5d13. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e d d e d '}
# Guessing letter: r
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ _ _ e d d e d '}
# Guessing letter: b
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ _ b e d d e d '}
# Guessing letter: a
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r _ _ _ b e d d e d '}
# Guessing letter: n
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r _ _ _ b e d d e d '}
# Guessing letter: s
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r _ s s b e d d e d '}
# Guessing letter: o
# Sever response: {'game_id': '726c7bde5d13', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r o s s b e d d e d '}
# Guessing letter: c
# Sever response: {'game_id': '726c7bde5d13', 'status': 'success', 'tries_remains': 4, 'word': 'c r o s s b e d d e d '}
# Successfully finished game: 726c7bde5d13
# run 991 recorded games. success rate so far = 0.594
#
#
#
# Playing  477  th game
# Successfully start a new game! Game ID: e02fbc29a5ca. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ t _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ t _ _ _ _ _ _ _ a _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ t _ _ _ _ _ _ _ a _ l e '}
# Guessing letter: b
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ t _ _ _ _ _ _ _ a b l e '}
# Guessing letter: n
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n e _ t _ n _ _ _ _ _ a b l e '}
# Guessing letter: x
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n e x t _ n _ _ _ _ _ a b l e '}
# Guessing letter: i
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n e x t i n _ _ i _ _ a b l e '}
# Guessing letter: o
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n e x t i n _ _ i _ _ a b l e '}
# Guessing letter: c
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n e x t i n _ _ i _ _ a b l e '}
# Guessing letter: g
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n e x t i n g _ i _ _ a b l e '}
# Guessing letter: u
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n e x t i n g u i _ _ a b l e '}
# Guessing letter: s
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n e x t i n g u i s _ a b l e '}
# Guessing letter: h
# Sever response: {'game_id': 'e02fbc29a5ca', 'status': 'success', 'tries_remains': 3, 'word': 'i n e x t i n g u i s h a b l e '}
# Successfully finished game: e02fbc29a5ca
# run 992 recorded games. success rate so far = 0.595
#
#
#
# Playing  478  th game
# Successfully start a new game! Game ID: dd0d6ef58132. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ t e '}
# Guessing letter: a
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ a _ _ _ _ t e '}
# Guessing letter: i
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ _ _ _ _ a _ _ _ _ t e '}
# Guessing letter: r
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ r _ _ _ a _ _ _ _ t e '}
# Guessing letter: o
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i _ r o _ _ a _ o _ _ t e '}
# Guessing letter: c
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i c r o _ _ a _ o c _ t e '}
# Guessing letter: y
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ i c r o _ _ a _ o c y t e '}
# Guessing letter: m
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 6, 'word': 'm i c r o _ _ a _ o c y t e '}
# Guessing letter: n
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm i c r o _ _ a _ o c y t e '}
# Guessing letter: p
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm i c r o p _ a _ o c y t e '}
# Guessing letter: h
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'ongoing', 'tries_remains': 5, 'word': 'm i c r o p h a _ o c y t e '}
# Guessing letter: g
# Sever response: {'game_id': 'dd0d6ef58132', 'status': 'success', 'tries_remains': 5, 'word': 'm i c r o p h a g o c y t e '}
# Successfully finished game: dd0d6ef58132
# run 993 recorded games. success rate so far = 0.595
#
#
#
# Playing  479  th game
# Successfully start a new game! Game ID: 9f33cac42a8d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ r _ _ _ r _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ t r _ _ _ r _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ t r _ _ _ r _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ t r _ _ _ r _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ t r _ _ _ r _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ t r _ a _ r a _ '}
# Guessing letter: l
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ t r _ a _ r a l '}
# Guessing letter: u
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ t r _ a u r a l '}
# Guessing letter: v
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ t r _ a u r a l '}
# Guessing letter: p
# Sever response: {'game_id': '9f33cac42a8d', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ t r _ a u r a l '}
# Failed game: 9f33cac42a8d. Because of: # of tries exceeded!
# run 994 recorded games. success rate so far = 0.595
#
#
#
# Playing  480  th game
# Successfully start a new game! Game ID: 63367ccf5b53. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '63367ccf5b53', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '63367ccf5b53', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '63367ccf5b53', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '63367ccf5b53', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '63367ccf5b53', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '63367ccf5b53', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ _ _ _ '}
# Failed game: 63367ccf5b53. Because of: # of tries exceeded!
# run 995 recorded games. success rate so far = 0.594
#
#
#
# Playing  481  th game
# Successfully start a new game! Game ID: ca5394df8875. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ _ i '}
# Guessing letter: l
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l i _ l i '}
# Guessing letter: o
# Sever response: {'game_id': 'ca5394df8875', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l i _ l i '}
# Guessing letter: d
# Sever response: {'game_id': 'ca5394df8875', 'status': 'failed', 'tries_remains': 0, 'word': 'l i _ l i '}
# Failed game: ca5394df8875. Because of: # of tries exceeded!
# run 996 recorded games. success rate so far = 0.593
#
#
#
# Playing  482  th game
# Successfully start a new game! Game ID: 410f3e1d2b22. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ r _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ r _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o o _ r o o _ '}
# Guessing letter: d
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o o _ r o o _ '}
# Guessing letter: m
# Sever response: {'game_id': '410f3e1d2b22', 'status': 'failed', 'tries_remains': 0, 'word': '_ o o _ r o o _ '}
# Failed game: 410f3e1d2b22. Because of: # of tries exceeded!
# run 997 recorded games. success rate so far = 0.593
#
#
#
# Playing  483  th game
# Successfully start a new game! Game ID: ded013eb791c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e r _ _ _ _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ e r _ _ _ _ _ _ _ e '}
# Guessing letter: p
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e p e r _ _ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e p e r _ _ _ _ _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e p e r _ _ n _ _ i _ e '}
# Guessing letter: v
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e p e r _ _ n _ _ i _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e p e r _ _ n a _ i _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e p e r _ _ n a l i _ e '}
# Guessing letter: z
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e p e r _ _ n a l i _ e '}
# Guessing letter: s
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e p e r s _ n a l i s e '}
# Guessing letter: o
# Sever response: {'game_id': 'ded013eb791c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e p e r s o n a l i s e '}
# Guessing letter: d
# Sever response: {'game_id': 'ded013eb791c', 'status': 'success', 'tries_remains': 3, 'word': 'd e p e r s o n a l i s e '}
# Successfully finished game: ded013eb791c
# run 998 recorded games. success rate so far = 0.593
#
#
#
# Playing  484  th game
# Successfully start a new game! Game ID: eeb290ac9694. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ '}
# Guessing letter: s
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ '}
# Guessing letter: l
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ l _ a _ '}
# Guessing letter: e
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ l _ a _ '}
# Guessing letter: i
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i l i a _ '}
# Guessing letter: n
# Sever response: {'game_id': 'eeb290ac9694', 'status': 'success', 'tries_remains': 4, 'word': 'i l i a n '}
# Successfully finished game: eeb290ac9694
# run 999 recorded games. success rate so far = 0.594
#
#
#
# Playing  485  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[33], line 4
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=True)
#       5 [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#       6 recorded_success_rate = total_recorded_successes / total_recorded_runs
#
# Cell In[4], line 111, in HangmanAPI.start_game(self, practice, verbose)
#     108 self.guessed_letters = []
#     109 self.current_dictionary = self.full_dictionary
# --> 111 response = self.request("/new_game", {"practice":practice})
#     112 if response.get('status')=="approved":
#     113     game_id = response.get('game_id')
#
# Cell In[4], line 213, in HangmanAPI.request(self, path, args, post_args, method)
#     210     raise HangmanAPIError('Maintype was not text, or querystring')
#     212 if result and isinstance(result, dict) and result.get("error"):
# --> 213     raise HangmanAPIError(result)
#     214 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)

print(total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes)
# Out:
# overall success rate = 0.593
# 392 1000 593 224
